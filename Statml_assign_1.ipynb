# %% [markdown]
# <a href="https://colab.research.google.com/github/varshithreddy07/statml-b40/blob/main/assignment1(statml).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
# Data
X = np.array([2.3, 2.5, 3.6, 2.8, 3.1, 2.9, 3.2, 2.7, 2.8, 3.0])
# Number of bins
num_bins = 5
# Compute histogram
counts, bin_edges = np.histogram(X, bins=num_bins)
# Compute bin width
bin_width = bin_edges[1] - bin_edges[0]
# Compute density
total_count = len(X)
density = counts / (total_count * bin_width)
# Print results
print("Bin edges:", bin_edges)
print("Counts per bin:", counts)
print("Density per bin:", density)
# Plot histogram
plt.hist(X, bins=num_bins, density=True, edgecolor='black')
plt.xlabel('Value')
plt.ylabel('Density')
plt.title('Histogram of Data with Density')
plt.show()
# Out:
# Bin edges: [2.3  2.56 2.82 3.08 3.34 3.6 ]
# Counts per bin: [2 3 2 2 1]
# Density per bin: [0.76923077 1.15384615 0.76923077 0.76923077 0.38461538]

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

# Data
x = np.array([4, 5, 5, 6, 8, 3, 2, 8, 4, 3, 2, 7, 5, 8])

# Pandas DataFrame for convenient calculations
data = pd.DataFrame({'x': x})

# Mean
mean_x = data['x'].mean()

# Median
median_x = data['x'].median()

# Mode
mode_x = data['x'].mode()[0]

# Variance
variance_x = data['x'].var()

# Standard Deviation
std_dev_x = data['x'].std()

# Range
range_x = data['x'].max() - data['x'].min()

# Interquartile Range (IQR)
iqr_x = data['x'].quantile(0.75) - data['x'].quantile(0.25)

# Skewness
skewness_x = data['x'].skew()

# Kurtosis
kurtosis_x = data['x'].kurtosis()

# Display results
results = {
    'Mean': mean_x,
    'Median': median_x,
    'Mode': mode_x,
    'Variance': variance_x,
    'Standard Deviation': std_dev_x,
    'Range': range_x,
    'IQR': iqr_x,
    'Skewness': skewness_x,
    'Kurtosis': kurtosis_x
}

print(results)

# Visualization with Matplotlib
plt.figure(figsize=(10, 6))

# Histogram
plt.subplot(1, 2, 1)
plt.hist(x, bins=range(min(x), max(x) + 1), edgecolor='black')
plt.title('Histogram')
plt.xlabel('Value')
plt.ylabel('Frequency')

# Box plot
plt.subplot(1, 2, 2)
plt.boxplot(x, vert=False)
plt.title('Box Plot')
plt.xlabel('Value')

plt.tight_layout()
plt.show()
# Out:
# {'Mean': 5.0, 'Median': 5.0, 'Mode': 5, 'Variance': 4.615384615384615, 'Standard Deviation': 2.1483446221182985, 'Range': 6, 'IQR': 3.5, 'Skewness': 0.16291613384397097, 'Kurtosis': -1.2212121212121212}
